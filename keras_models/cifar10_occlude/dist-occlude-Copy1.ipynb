# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from pprint import pprint
import random
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
num_classes = 10
epochs = 100
data_augmentation = True
model_type = 'resnet'
input_shape = (32, 32, 3)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models_distocclude')
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
    
model_name = 'cifar10occlude_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
Input = keras.layers.Input
Conv2D = keras.layers.Conv2D
Activation = keras.layers.Activation
BatchNormalization = keras.layers.BatchNormalization
AveragePooling2D = keras.layers.AveragePooling2D
Flatten = keras.layers.Flatten
Dropout = keras.layers.Dropout
Dense = keras.layers.Dense

def block_bac(inputs, filters, activation='relu', kernel_size=1, strides=1, padding='same'):
    b = BatchNormalization()(inputs)
    a = Activation(activation)(b)
    c = Conv2D(filters, kernel_size, strides=strides, padding=padding)(a)
    return c

def block_res(inputs, small, large, firstlayer=False, firststride=2, returnshortcut=False):
    if firstlayer:
        s = Conv2D(filters=large, kernel_size=1, padding='same', strides=firststride)(inputs)
    else:
        s = inputs
    c = block_bac(inputs, filters=small, kernel_size=1)
    c = block_bac(c, filters=small, kernel_size=3)
    if firstlayer:
        c = block_bac(c, filters=large, kernel_size=1, strides=firststride)
    else:
        c = block_bac(c, filters=large, kernel_size=1, strides=1)
    if returnshortcut:
        return keras.layers.add([c, s]), s
    else:
        return keras.layers.add([c, s])
    

# Input block
i = Input(shape=input_shape)
c = Conv2D(filters=16, kernel_size=3, padding='same')(i)
b = BatchNormalization()(c)
a = Activation('relu')(b)

r, s = block_res(a, 16, 64, firstlayer=True, firststride=1, returnshortcut=True)
r, s = block_res(s, 64, 128, firstlayer=True, returnshortcut=True)
r, s = block_res(s, 128, 256, firstlayer=True, returnshortcut=True)
b = BatchNormalization()(s)

# r = block_res(a, 16, 64, firstlayer=True, firststride=1)
# r = block_res(r, 16, 64)
# r = block_res(r, 16, 64)

# r = block_res(r, 64, 128, firstlayer=True)
# r = block_res(r, 64, 128)
# r = block_res(r, 64, 128)

# r = block_res(r, 128, 256, firstlayer=True)
# r = block_res(r, 128, 256)
# r = block_res(r, 128, 256)

# b = BatchNormalization()(r)
a = Activation('relu')(b)
av = AveragePooling2D(8)(a)
f = Flatten()(av)
d = Dense(num_classes)(f)
ac = Activation('softmax')(d)

model = keras.Model(inputs=i, outputs=ac)

keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = keras.callbacks.ModelCheckpoint(filepath=filepath,
                                             monitor='loss',
                                             verbose=1,
                                             save_best_only=True)

lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)

lr_reducer = keras.callbacks.ReduceLROnPlateau(factor=np.sqrt(0.1),
                                               cooldown=0,
                                               patience=5,
                                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
def occlude(img):
    x, y = np.random.randint(5, 20, 2)
    w, h = np.random.randint(10, 20, 2)
    img[x:x+w, y:y+h, :] = np.random.randint(100, 200, 3)
    return img

def occlude_all(X):
    for j in range(len(X)):
        X[j] = occlude(X[j])
    return X

(X_train_raw, y_train_raw), (X_test_raw, y_test_raw) = keras.datasets.cifar10.load_data()
X_train_raw.shape, y_train_raw.shape, X_test_raw.shape, y_test_raw.shape

X_train_occ = occlude_all(X_train_raw.copy())
X_test_occ = occlude_all(X_test_raw.copy())

X_train = np.concatenate([X_train_raw, X_train_occ])
y_train = np.concatenate([y_train_raw * 0, y_train_raw * 0 + 1])
X_test = np.concatenate([X_test_raw, X_test_occ])
y_test = np.concatenate([y_test_raw * 0, y_test_raw * 0 + 1])

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10, 10))
for i in range(9):
    j = random.choice(range(len(X_train)))
    ax = fig.add_subplot(3, 3, i+1)
    ax.imshow(X_train[j], interpolation='bilinear')
    ax.set_title('{}'.format(classes[y_train[j][0]]))
    ax.axis('off')
fig.tight_layout()

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (100000, 32, 32, 3)
# y_train shape: (100000, 1)
# 100000 train samples
# 20000 test samples

# %%
# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Subtract pixel mean is enabled
X_train_mean = np.mean(X_train, axis=0)
X_train -= X_train_mean
X_test -= X_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

datagen = keras.preprocessing.image.ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

datagen.fit(X_train)

# %%
fig = plt.figure(figsize=(5, 5))
for i in range(3):
    ax1 = fig.add_subplot(3, 2, i*2+1)
    ax2 = fig.add_subplot(3, 2, i*2+2)
    
    j = random.choice(range(len(X_train)))
    x = X_train[j]
    y = datagen.random_transform(x)
    
    ax1.imshow(x[:, :, 0], interpolation='bilinear')
    ax1.set_title("Raw")
    ax1.axis('off')
    
    ax2.imshow(y[:, :, 0], interpolation='bilinear')
    ax2.set_title("Transform")
    ax2.axis('off')
fig.tight_layout()

# %%
model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                    epochs=40,
                    validation_data=(X_test, y_test),
                    workers=32,
                    callbacks=callbacks)
# Out:
# Epoch 1/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 105s 34ms/step - loss: 0.4698 - accuracy: 0.7875 - val_loss: 0.4712 - val_accuracy: 0.7991
#
# Epoch 00001: loss improved from inf to 0.46983, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.001.h5
# Epoch 2/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.3985 - accuracy: 0.8297 - val_loss: 0.3716 - val_accuracy: 0.8482
#
# Epoch 00002: loss improved from 0.46983 to 0.39853, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.002.h5
# Epoch 3/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.3701 - accuracy: 0.8465 - val_loss: 0.3338 - val_accuracy: 0.8747
#
# Epoch 00003: loss improved from 0.39853 to 0.37015, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.003.h5
# Epoch 4/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 101s 32ms/step - loss: 0.3481 - accuracy: 0.8595 - val_loss: 0.2778 - val_accuracy: 0.8975
#
# Epoch 00004: loss improved from 0.37015 to 0.34807, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.004.h5
# Epoch 5/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 101s 32ms/step - loss: 0.3251 - accuracy: 0.8703 - val_loss: 0.2963 - val_accuracy: 0.8741
#
# Epoch 00005: loss improved from 0.34807 to 0.32507, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.005.h5
# Epoch 6/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 97s 31ms/step - loss: 0.3048 - accuracy: 0.8830 - val_loss: 0.2559 - val_accuracy: 0.8980
#
# Epoch 00006: loss improved from 0.32507 to 0.30485, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.006.h5
# Epoch 7/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 95s 30ms/step - loss: 0.2804 - accuracy: 0.8938 - val_loss: 0.3960 - val_accuracy: 0.8648
#
# Epoch 00007: loss improved from 0.30485 to 0.28043, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.007.h5
# Epoch 8/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 94s 30ms/step - loss: 0.2641 - accuracy: 0.9032 - val_loss: 0.2274 - val_accuracy: 0.9302
#
# Epoch 00008: loss improved from 0.28043 to 0.26407, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.008.h5
# Epoch 9/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 96s 31ms/step - loss: 0.2473 - accuracy: 0.9109 - val_loss: 0.2319 - val_accuracy: 0.9353
#
# Epoch 00009: loss improved from 0.26407 to 0.24729, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.009.h5
# Epoch 10/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 95s 30ms/step - loss: 0.2367 - accuracy: 0.9173 - val_loss: 0.2308 - val_accuracy: 0.9207
#
# Epoch 00010: loss improved from 0.24729 to 0.23670, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.010.h5
# Epoch 11/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 93s 30ms/step - loss: 0.2238 - accuracy: 0.9220 - val_loss: 0.2252 - val_accuracy: 0.9367
#
# Epoch 00011: loss improved from 0.23670 to 0.22383, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.011.h5
# Epoch 12/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 95s 30ms/step - loss: 0.2174 - accuracy: 0.9258 - val_loss: 0.8145 - val_accuracy: 0.6584
#
# Epoch 00012: loss improved from 0.22383 to 0.21736, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.012.h5
# Epoch 13/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 94s 30ms/step - loss: 0.2118 - accuracy: 0.9276 - val_loss: 0.1958 - val_accuracy: 0.9430
#
# Epoch 00013: loss improved from 0.21736 to 0.21179, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.013.h5
# Epoch 14/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 105s 34ms/step - loss: 0.2042 - accuracy: 0.9312 - val_loss: 0.1603 - val_accuracy: 0.9404
#
# Epoch 00014: loss improved from 0.21179 to 0.20422, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.014.h5
# Epoch 15/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.2013 - accuracy: 0.9322 - val_loss: 0.1475 - val_accuracy: 0.9557
#
# Epoch 00015: loss improved from 0.20422 to 0.20125, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.015.h5
# Epoch 16/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.2001 - accuracy: 0.9326 - val_loss: 0.1764 - val_accuracy: 0.9387
#
# Epoch 00016: loss improved from 0.20125 to 0.20012, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.016.h5
# Epoch 17/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.1938 - accuracy: 0.9359 - val_loss: 0.1460 - val_accuracy: 0.9610
#
# Epoch 00017: loss improved from 0.20012 to 0.19380, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.017.h5
# Epoch 18/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 104s 33ms/step - loss: 0.1896 - accuracy: 0.9370 - val_loss: 0.2103 - val_accuracy: 0.9327
#
# Epoch 00018: loss improved from 0.19380 to 0.18964, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.018.h5
# Epoch 19/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 105s 34ms/step - loss: 0.1882 - accuracy: 0.9384 - val_loss: 0.1521 - val_accuracy: 0.9567
#
# Epoch 00019: loss improved from 0.18964 to 0.18820, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.019.h5
# Epoch 20/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 104s 33ms/step - loss: 0.1846 - accuracy: 0.9391 - val_loss: 0.2052 - val_accuracy: 0.9530
#
# Epoch 00020: loss improved from 0.18820 to 0.18463, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.020.h5
# Epoch 21/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 104s 33ms/step - loss: 0.1818 - accuracy: 0.9400 - val_loss: 0.4426 - val_accuracy: 0.8693
#
# Epoch 00021: loss improved from 0.18463 to 0.18181, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.021.h5
# Epoch 22/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 105s 34ms/step - loss: 0.1753 - accuracy: 0.9437 - val_loss: 0.1917 - val_accuracy: 0.9488
#
# Epoch 00022: loss improved from 0.18181 to 0.17533, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.022.h5
# Epoch 23/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 101s 32ms/step - loss: 0.1750 - accuracy: 0.9430 - val_loss: 0.2689 - val_accuracy: 0.9381
#
# Epoch 00023: loss improved from 0.17533 to 0.17499, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.023.h5
# Epoch 24/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.1741 - accuracy: 0.9433 - val_loss: 0.1574 - val_accuracy: 0.9640
#
# Epoch 00024: loss improved from 0.17499 to 0.17407, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.024.h5
# Epoch 25/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 99s 32ms/step - loss: 0.1707 - accuracy: 0.9457 - val_loss: 0.1246 - val_accuracy: 0.9582
#
# Epoch 00025: loss improved from 0.17407 to 0.17069, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.025.h5
# Epoch 26/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 100s 32ms/step - loss: 0.1710 - accuracy: 0.9455 - val_loss: 0.1407 - val_accuracy: 0.9578
#
# Epoch 00026: loss did not improve from 0.17069
# Epoch 27/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 98s 31ms/step - loss: 0.1650 - accuracy: 0.9474 - val_loss: 0.1968 - val_accuracy: 0.9502
#
# Epoch 00027: loss improved from 0.17069 to 0.16502, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.027.h5
# Epoch 28/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 95s 30ms/step - loss: 0.1639 - accuracy: 0.9485 - val_loss: 0.4414 - val_accuracy: 0.8866
#
# Epoch 00028: loss improved from 0.16502 to 0.16390, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.028.h5
# Epoch 29/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 102s 33ms/step - loss: 0.1642 - accuracy: 0.9477 - val_loss: 0.1981 - val_accuracy: 0.9153
#
# Epoch 00029: loss did not improve from 0.16390
# Epoch 30/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 97s 31ms/step - loss: 0.1600 - accuracy: 0.9493 - val_loss: 0.1246 - val_accuracy: 0.9671
#
# Epoch 00030: loss improved from 0.16390 to 0.16003, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.030.h5
# Epoch 31/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 106s 34ms/step - loss: 0.1558 - accuracy: 0.9509 - val_loss: 0.1231 - val_accuracy: 0.9700
#
# Epoch 00031: loss improved from 0.16003 to 0.15580, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.031.h5
# Epoch 32/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 104s 33ms/step - loss: 0.1524 - accuracy: 0.9514 - val_loss: 0.1091 - val_accuracy: 0.9725
#
# Epoch 00032: loss improved from 0.15580 to 0.15241, saving model to /home/zcc/Documents/cifar10_occlude/saved_models_distocclude/cifar10occlude_resnet_model.032.h5
# Epoch 33/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 103s 33ms/step - loss: 0.1540 - accuracy: 0.9514 - val_loss: 0.1136 - val_accuracy: 0.9707
#
# Epoch 00033: loss did not improve from 0.15241
# Epoch 34/40
# Learning rate:  0.001
# 3125/3125 [==============================] - 97s 31ms/step - loss: 0.1524 - accuracy: 0.9522 - val_loss: 0.1156 - val_accuracy: 0.9644
#
# Epoch 00034: loss did not improve from 0.15241
# Epoch 35/40
# Learning rate:  0.001
# 2033/3125 [==================>...........] - ETA: 33s - loss: 0.1521 - accuracy: 0.9523

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
