# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from pprint import pprint
import random
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
num_classes = 10
epochs = 100
data_augmentation = True
model_type = 'resnet'
input_shape = (32, 32, 3)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
    
model_name = 'cifar10occlude_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
Input = keras.layers.Input
Conv2D = keras.layers.Conv2D
Activation = keras.layers.Activation
BatchNormalization = keras.layers.BatchNormalization
AveragePooling2D = keras.layers.AveragePooling2D
Flatten = keras.layers.Flatten
Dropout = keras.layers.Dropout
Dense = keras.layers.Dense

def block_bac(inputs, filters, activation='relu', kernel_size=1, strides=1, padding='same'):
    b = BatchNormalization()(inputs)
    a = Activation(activation)(b)
    c = Conv2D(filters, kernel_size, strides=strides, padding=padding)(a)
    return c

def block_res(inputs, small, large, firstlayer=False, firststride=2):
    if firstlayer:
        s = Conv2D(filters=large, kernel_size=1, padding='same', strides=firststride)(inputs)
    else:
        s = inputs
    c = block_bac(inputs, filters=small, kernel_size=1)
    c = block_bac(c, filters=small, kernel_size=3)
    if firstlayer:
        c = block_bac(c, filters=large, kernel_size=1, strides=firststride)
    else:
        c = block_bac(c, filters=large, kernel_size=1, strides=1)
    return keras.layers.add([c, s])
    

# Input block
i = Input(shape=input_shape)
c = Conv2D(filters=16, kernel_size=3, padding='same')(i)
b = BatchNormalization()(c)
a = Activation('relu')(b)

r = block_res(a, 16, 64, firstlayer=True, firststride=1)
r = block_res(r, 16, 64)
r = block_res(r, 16, 64)

r = block_res(r, 64, 128, firstlayer=True)
r = block_res(r, 64, 128)
r = block_res(r, 64, 128)

r = block_res(r, 128, 256, firstlayer=True)
r = block_res(r, 128, 256)
r = block_res(r, 128, 256)

b = BatchNormalization()(r)
a = Activation('relu')(b)
av = AveragePooling2D(8)(a)
f = Flatten()(av)
d = Dense(num_classes)(f)
ac = Activation('softmax')(d)

model = keras.Model(inputs=i, outputs=ac)

keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = keras.callbacks.ModelCheckpoint(filepath=filepath,
                                             monitor='loss',
                                             verbose=1,
                                             save_best_only=True)

lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)

lr_reducer = keras.callbacks.ReduceLROnPlateau(factor=np.sqrt(0.1),
                                               cooldown=0,
                                               patience=5,
                                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
def occlude(img):
    x, y = np.random.randint(5, 20, 2)
    w, h = np.random.randint(10, 20, 2)
    img[x:x+w, y:y+h, :] = np.random.randint(100, 200, 3)
    return img

(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape

for j in range(len(X_train)):
    X_train[j] = occlude(X_train[j])
    
for j in range(len(X_test)):
    X_test[j] = occlude(X_test[j])

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10, 10))
for i in range(9):
    j = random.choice(range(len(X_train)))
    ax = fig.add_subplot(3, 3, i+1)
    ax.imshow(X_train[j], interpolation='bilinear')
    ax.set_title('{}'.format(classes[y_train[j][0]]))
    ax.axis('off')
fig.tight_layout()

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# 50000 train samples
# 10000 test samples

# %%
# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Subtract pixel mean is enabled
X_train_mean = np.mean(X_train, axis=0)
X_train -= X_train_mean
X_test -= X_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

datagen = keras.preprocessing.image.ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

datagen.fit(X_train)

# %%
fig = plt.figure(figsize=(5, 5))
for i in range(3):
    ax1 = fig.add_subplot(3, 2, i*2+1)
    ax2 = fig.add_subplot(3, 2, i*2+2)
    
    j = random.choice(range(len(X_train)))
    x = X_train[j]
    y = datagen.random_transform(x)
    
    ax1.imshow(x[:, :, 0], interpolation='bilinear')
    ax1.set_title("Raw")
    ax1.axis('off')
    
    ax2.imshow(y[:, :, 0], interpolation='bilinear')
    ax2.set_title("Transform")
    ax2.axis('off')
fig.tight_layout()

# %%
model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                    epochs=200,
                    validation_data=(X_test, y_test),
                    workers=32,
                    callbacks=callbacks)
# Out:
# Epoch 1/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 134s 86ms/step - loss: 1.5570 - accuracy: 0.4353 - val_loss: 2.5325 - val_accuracy: 0.3248
#
# Epoch 00001: loss improved from inf to 1.55702, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.001.h5
# Epoch 2/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 118s 75ms/step - loss: 1.2349 - accuracy: 0.5577 - val_loss: 1.5319 - val_accuracy: 0.5061
#
# Epoch 00002: loss improved from 1.55702 to 1.23490, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.002.h5
# Epoch 3/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 1.0902 - accuracy: 0.6137 - val_loss: 1.0573 - val_accuracy: 0.6165
#
# Epoch 00003: loss improved from 1.23490 to 1.09021, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.003.h5
# Epoch 4/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.9780 - accuracy: 0.6560 - val_loss: 1.3291 - val_accuracy: 0.6159
#
# Epoch 00004: loss improved from 1.09021 to 0.97804, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.004.h5
# Epoch 5/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.9037 - accuracy: 0.6825 - val_loss: 0.9650 - val_accuracy: 0.6632
#
# Epoch 00005: loss improved from 0.97804 to 0.90376, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.005.h5
# Epoch 6/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.8489 - accuracy: 0.7044 - val_loss: 0.8746 - val_accuracy: 0.6922
#
# Epoch 00006: loss improved from 0.90376 to 0.84890, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.006.h5
# Epoch 7/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 78ms/step - loss: 0.8067 - accuracy: 0.7189 - val_loss: 0.9457 - val_accuracy: 0.6662
#
# Epoch 00007: loss improved from 0.84890 to 0.80667, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.007.h5
# Epoch 8/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.7643 - accuracy: 0.7344 - val_loss: 0.9920 - val_accuracy: 0.6717
#
# Epoch 00008: loss improved from 0.80667 to 0.76434, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.008.h5
# Epoch 9/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.7366 - accuracy: 0.7429 - val_loss: 0.8434 - val_accuracy: 0.7147
#
# Epoch 00009: loss improved from 0.76434 to 0.73664, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.009.h5
# Epoch 10/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.6983 - accuracy: 0.7565 - val_loss: 0.9568 - val_accuracy: 0.7005
#
# Epoch 00010: loss improved from 0.73664 to 0.69832, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.010.h5
# Epoch 11/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 123s 79ms/step - loss: 0.6709 - accuracy: 0.7663 - val_loss: 0.7579 - val_accuracy: 0.7383
#
# Epoch 00011: loss improved from 0.69832 to 0.67082, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.011.h5
# Epoch 12/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.6487 - accuracy: 0.7740 - val_loss: 0.7056 - val_accuracy: 0.7577
#
# Epoch 00012: loss improved from 0.67082 to 0.64872, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.012.h5
# Epoch 13/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.6243 - accuracy: 0.7831 - val_loss: 0.7109 - val_accuracy: 0.7611
#
# Epoch 00013: loss improved from 0.64872 to 0.62430, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.013.h5
# Epoch 14/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.6077 - accuracy: 0.7891 - val_loss: 0.9574 - val_accuracy: 0.7022
#
# Epoch 00014: loss improved from 0.62430 to 0.60764, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.014.h5
# Epoch 15/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.5884 - accuracy: 0.7954 - val_loss: 0.8349 - val_accuracy: 0.7334
#
# Epoch 00015: loss improved from 0.60764 to 0.58852, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.015.h5
# Epoch 16/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.5666 - accuracy: 0.8019 - val_loss: 0.8107 - val_accuracy: 0.7261
#
# Epoch 00016: loss improved from 0.58852 to 0.56658, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.016.h5
# Epoch 17/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.5569 - accuracy: 0.8071 - val_loss: 0.6294 - val_accuracy: 0.7880
#
# Epoch 00017: loss improved from 0.56658 to 0.55686, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.017.h5
# Epoch 18/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.5434 - accuracy: 0.8085 - val_loss: 0.7770 - val_accuracy: 0.7411
#
# Epoch 00018: loss improved from 0.55686 to 0.54345, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.018.h5
# Epoch 19/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5226 - accuracy: 0.8173 - val_loss: 0.7482 - val_accuracy: 0.7575
#
# Epoch 00019: loss improved from 0.54345 to 0.52233, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.019.h5
# Epoch 20/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.5147 - accuracy: 0.8194 - val_loss: 0.6626 - val_accuracy: 0.7765
#
# Epoch 00020: loss improved from 0.52233 to 0.51476, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.020.h5
# Epoch 21/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.5016 - accuracy: 0.8245 - val_loss: 0.6709 - val_accuracy: 0.7790
#
# Epoch 00021: loss improved from 0.51476 to 0.50158, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.021.h5
# Epoch 22/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.4957 - accuracy: 0.8266 - val_loss: 0.6166 - val_accuracy: 0.7931
#
# Epoch 00022: loss improved from 0.50158 to 0.49562, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.022.h5
# Epoch 23/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4787 - accuracy: 0.8312 - val_loss: 0.5960 - val_accuracy: 0.7988
#
# Epoch 00023: loss improved from 0.49562 to 0.47864, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.023.h5
# Epoch 24/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.4670 - accuracy: 0.8373 - val_loss: 0.6188 - val_accuracy: 0.7973
#
# Epoch 00024: loss improved from 0.47864 to 0.46701, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.024.h5
# Epoch 25/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.4589 - accuracy: 0.8407 - val_loss: 0.5960 - val_accuracy: 0.8046
#
# Epoch 00025: loss improved from 0.46701 to 0.45895, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.025.h5
# Epoch 26/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 78ms/step - loss: 0.4496 - accuracy: 0.8403 - val_loss: 0.6232 - val_accuracy: 0.7951
#
# Epoch 00026: loss improved from 0.45895 to 0.44964, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.026.h5
# Epoch 27/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.4358 - accuracy: 0.8479 - val_loss: 0.6431 - val_accuracy: 0.7895
#
# Epoch 00027: loss improved from 0.44964 to 0.43570, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.027.h5
# Epoch 28/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.4301 - accuracy: 0.8496 - val_loss: 0.6752 - val_accuracy: 0.7836
#
# Epoch 00028: loss improved from 0.43570 to 0.43016, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.028.h5
# Epoch 29/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.4188 - accuracy: 0.8539 - val_loss: 0.6929 - val_accuracy: 0.7834
#
# Epoch 00029: loss improved from 0.43016 to 0.41873, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.029.h5
# Epoch 30/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.4079 - accuracy: 0.8568 - val_loss: 0.6017 - val_accuracy: 0.8060
#
# Epoch 00030: loss improved from 0.41873 to 0.40776, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.030.h5
# Epoch 31/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.4039 - accuracy: 0.8599 - val_loss: 0.7108 - val_accuracy: 0.7807
#
# Epoch 00031: loss improved from 0.40776 to 0.40394, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.031.h5
# Epoch 32/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 123s 79ms/step - loss: 0.3964 - accuracy: 0.8612 - val_loss: 0.6042 - val_accuracy: 0.8058
#
# Epoch 00032: loss improved from 0.40394 to 0.39635, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.032.h5
# Epoch 33/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.3902 - accuracy: 0.8611 - val_loss: 0.6034 - val_accuracy: 0.8039
#
# Epoch 00033: loss improved from 0.39635 to 0.39001, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.033.h5
# Epoch 34/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 78ms/step - loss: 0.3796 - accuracy: 0.8672 - val_loss: 0.6940 - val_accuracy: 0.7938
#
# Epoch 00034: loss improved from 0.39001 to 0.37964, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.034.h5
# Epoch 35/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.3720 - accuracy: 0.8680 - val_loss: 0.5794 - val_accuracy: 0.8101
#
# Epoch 00035: loss improved from 0.37964 to 0.37193, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.035.h5
# Epoch 36/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.3648 - accuracy: 0.8711 - val_loss: 0.5632 - val_accuracy: 0.8204
#
# Epoch 00036: loss improved from 0.37193 to 0.36481, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.036.h5
# Epoch 37/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.3598 - accuracy: 0.8726 - val_loss: 0.5527 - val_accuracy: 0.8224
#
# Epoch 00037: loss improved from 0.36481 to 0.35981, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.037.h5
# Epoch 38/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.3522 - accuracy: 0.8782 - val_loss: 0.6453 - val_accuracy: 0.8040
#
# Epoch 00038: loss improved from 0.35981 to 0.35221, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.038.h5
# Epoch 39/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.3435 - accuracy: 0.8791 - val_loss: 0.6130 - val_accuracy: 0.8066
#
# Epoch 00039: loss improved from 0.35221 to 0.34361, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.039.h5
# Epoch 40/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.3406 - accuracy: 0.8802 - val_loss: 0.5806 - val_accuracy: 0.8184
#
# Epoch 00040: loss improved from 0.34361 to 0.34045, saving model to /home/zcc/Documents/cifar10_occlude/saved_models/cifar10occlude_resnet_model.040.h5

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 5s 529us/step
# Test loss: 0.5805726888298989
# Test accuracy: 0.8184000253677368
