# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from pprint import pprint
import random
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
num_classes = 10
epochs = 100
data_augmentation = True
model_type = 'resnet'
input_shape = (32, 32, 3)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
Input = keras.layers.Input
Conv2D = keras.layers.Conv2D
Activation = keras.layers.Activation
BatchNormalization = keras.layers.BatchNormalization
AveragePooling2D = keras.layers.AveragePooling2D
Flatten = keras.layers.Flatten
Dropout = keras.layers.Dropout
Dense = keras.layers.Dense

def block_bac(inputs, filters, activation='relu', kernel_size=1, strides=1, padding='same'):
    b = BatchNormalization()(inputs)
    a = Activation(activation)(b)
    c = Conv2D(filters, kernel_size, strides=strides, padding=padding)(a)
    return c

def block_res(inputs, small, large, firstlayer=False, firststride=2):
    if firstlayer:
        s = Conv2D(filters=large, kernel_size=1, padding='same', strides=firststride)(inputs)
    else:
        s = inputs
    c = block_bac(inputs, filters=small, kernel_size=1)
    c = block_bac(c, filters=small, kernel_size=3)
    if firstlayer:
        c = block_bac(c, filters=large, kernel_size=1, strides=firststride)
    else:
        c = block_bac(c, filters=large, kernel_size=1, strides=1)
    return keras.layers.add([c, s])
    

# Input block
i = Input(shape=input_shape)
c = Conv2D(filters=16, kernel_size=3, padding='same')(i)
b = BatchNormalization()(c)
a = Activation('relu')(b)

r = block_res(a, 16, 64, firstlayer=True, firststride=1)
r = block_res(r, 16, 64)
r = block_res(r, 16, 64)

r = block_res(r, 64, 128, firstlayer=True)
r = block_res(r, 64, 128)
r = block_res(r, 64, 128)

r = block_res(r, 128, 256, firstlayer=True)
r = block_res(r, 128, 256)
r = block_res(r, 128, 256)

b = BatchNormalization()(r)
a = Activation('relu')(b)
av = AveragePooling2D(8)(a)
f = Flatten()(av)
d = Dense(num_classes)(f)
ac = Activation('softmax')(d)

model = keras.Model(inputs=i, outputs=ac)

keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = keras.callbacks.ModelCheckpoint(filepath=filepath,
                                             monitor='loss',
                                             verbose=1,
                                             save_best_only=True)

lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)

lr_reducer = keras.callbacks.ReduceLROnPlateau(factor=np.sqrt(0.1),
                                               cooldown=0,
                                               patience=5,
                                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10, 10))
for i in range(9):
    j = random.choice(range(len(X_train)))
    ax = fig.add_subplot(3, 3, i+1)
    ax.imshow(X_train[j], interpolation='bilinear')
    ax.set_title('{}'.format(classes[y_train[j][0]]))
    ax.axis('off')
fig.tight_layout()

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# 50000 train samples
# 10000 test samples

# %%
# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Subtract pixel mean is enabled
X_train_mean = np.mean(X_train, axis=0)
X_train -= X_train_mean
X_test -= X_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

datagen = keras.preprocessing.image.ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

datagen.fit(X_train)

# %%
fig = plt.figure(figsize=(5, 5))
for i in range(3):
    ax1 = fig.add_subplot(3, 2, i*2+1)
    ax2 = fig.add_subplot(3, 2, i*2+2)
    
    j = random.choice(range(len(X_train)))
    x = X_train[j]
    y = datagen.random_transform(x)
    
    ax1.imshow(x[:, :, 0], interpolation='bilinear')
    ax1.set_title("Raw")
    ax1.axis('off')
    
    ax2.imshow(y[:, :, 0], interpolation='bilinear')
    ax2.set_title("Transform")
    ax2.axis('off')
fig.tight_layout()

# %%
model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                    epochs=40,
                    validation_data=(X_test, y_test),
                    workers=32,
                    callbacks=callbacks)
# Out:
# Epoch 1/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 128s 82ms/step - loss: 1.3602 - accuracy: 0.5060 - val_loss: 1.2805 - val_accuracy: 0.5641
#
# Epoch 00001: loss improved from inf to 1.36004, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.001.h5
# Epoch 2/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.9811 - accuracy: 0.6522 - val_loss: 1.0068 - val_accuracy: 0.6487
#
# Epoch 00002: loss improved from 1.36004 to 0.98103, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.002.h5
# Epoch 3/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.8155 - accuracy: 0.7130 - val_loss: 0.8501 - val_accuracy: 0.7163
#
# Epoch 00003: loss improved from 0.98103 to 0.81552, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.003.h5
# Epoch 4/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 110s 71ms/step - loss: 0.7085 - accuracy: 0.7555 - val_loss: 1.0162 - val_accuracy: 0.6798
#
# Epoch 00004: loss improved from 0.81552 to 0.70847, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.004.h5
# Epoch 5/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.6450 - accuracy: 0.7754 - val_loss: 0.8340 - val_accuracy: 0.7298
#
# Epoch 00005: loss improved from 0.70847 to 0.64507, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.005.h5
# Epoch 6/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.5919 - accuracy: 0.7950 - val_loss: 0.7840 - val_accuracy: 0.7490
#
# Epoch 00006: loss improved from 0.64507 to 0.59202, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.006.h5
# Epoch 7/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.5537 - accuracy: 0.8096 - val_loss: 0.7977 - val_accuracy: 0.7510
#
# Epoch 00007: loss improved from 0.59202 to 0.55349, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.007.h5
# Epoch 8/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.5209 - accuracy: 0.8213 - val_loss: 0.6607 - val_accuracy: 0.7859
#
# Epoch 00008: loss improved from 0.55349 to 0.52095, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.008.h5
# Epoch 9/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.4900 - accuracy: 0.8312 - val_loss: 0.7064 - val_accuracy: 0.7737
#
# Epoch 00009: loss improved from 0.52095 to 0.48995, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.009.h5
# Epoch 10/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.4623 - accuracy: 0.8383 - val_loss: 0.8538 - val_accuracy: 0.7373
#
# Epoch 00010: loss improved from 0.48995 to 0.46233, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.010.h5
# Epoch 11/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.4383 - accuracy: 0.8488 - val_loss: 0.5379 - val_accuracy: 0.8175
#
# Epoch 00011: loss improved from 0.46233 to 0.43829, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.011.h5
# Epoch 12/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.4225 - accuracy: 0.8548 - val_loss: 0.5777 - val_accuracy: 0.8047
#
# Epoch 00012: loss improved from 0.43829 to 0.42244, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.012.h5
# Epoch 13/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.4045 - accuracy: 0.8598 - val_loss: 0.4642 - val_accuracy: 0.8471
#
# Epoch 00013: loss improved from 0.42244 to 0.40446, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.013.h5
# Epoch 14/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.3857 - accuracy: 0.8668 - val_loss: 0.5457 - val_accuracy: 0.8181
#
# Epoch 00014: loss improved from 0.40446 to 0.38581, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.014.h5
# Epoch 15/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.3662 - accuracy: 0.8738 - val_loss: 0.6318 - val_accuracy: 0.8019
#
# Epoch 00015: loss improved from 0.38581 to 0.36618, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.015.h5
# Epoch 16/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.3577 - accuracy: 0.8753 - val_loss: 0.4224 - val_accuracy: 0.8615
#
# Epoch 00016: loss improved from 0.36618 to 0.35750, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.016.h5
# Epoch 17/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 110s 71ms/step - loss: 0.3436 - accuracy: 0.8796 - val_loss: 0.5136 - val_accuracy: 0.8295
#
# Epoch 00017: loss improved from 0.35750 to 0.34356, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.017.h5
# Epoch 18/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.3297 - accuracy: 0.8852 - val_loss: 0.4522 - val_accuracy: 0.8577
#
# Epoch 00018: loss improved from 0.34356 to 0.32975, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.018.h5
# Epoch 19/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.3188 - accuracy: 0.8895 - val_loss: 0.4603 - val_accuracy: 0.8496
#
# Epoch 00019: loss improved from 0.32975 to 0.31874, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.019.h5
# Epoch 20/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.3089 - accuracy: 0.8919 - val_loss: 0.5019 - val_accuracy: 0.8346
#
# Epoch 00020: loss improved from 0.31874 to 0.30889, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.020.h5
# Epoch 21/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.3010 - accuracy: 0.8947 - val_loss: 0.4655 - val_accuracy: 0.8505
#
# Epoch 00021: loss improved from 0.30889 to 0.30104, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.021.h5
# Epoch 22/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.2875 - accuracy: 0.8987 - val_loss: 0.3813 - val_accuracy: 0.8721
#
# Epoch 00022: loss improved from 0.30104 to 0.28756, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.022.h5
# Epoch 23/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.2849 - accuracy: 0.9014 - val_loss: 0.4930 - val_accuracy: 0.8462
#
# Epoch 00023: loss improved from 0.28756 to 0.28472, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.023.h5
# Epoch 24/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.2747 - accuracy: 0.9025 - val_loss: 0.4494 - val_accuracy: 0.8576
#
# Epoch 00024: loss improved from 0.28472 to 0.27458, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.024.h5
# Epoch 25/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.2671 - accuracy: 0.9073 - val_loss: 0.4309 - val_accuracy: 0.8668
#
# Epoch 00025: loss improved from 0.27458 to 0.26716, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.025.h5
# Epoch 26/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 110s 71ms/step - loss: 0.2550 - accuracy: 0.9097 - val_loss: 0.4163 - val_accuracy: 0.8699
#
# Epoch 00026: loss improved from 0.26716 to 0.25494, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.026.h5
# Epoch 27/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.2499 - accuracy: 0.9122 - val_loss: 0.4431 - val_accuracy: 0.8607
#
# Epoch 00027: loss improved from 0.25494 to 0.24984, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.027.h5
# Epoch 28/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 110s 71ms/step - loss: 0.2399 - accuracy: 0.9146 - val_loss: 0.4477 - val_accuracy: 0.8662
#
# Epoch 00028: loss improved from 0.24984 to 0.23988, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.028.h5
# Epoch 29/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.2327 - accuracy: 0.9186 - val_loss: 0.4514 - val_accuracy: 0.8591
#
# Epoch 00029: loss improved from 0.23988 to 0.23270, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.029.h5
# Epoch 30/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.2296 - accuracy: 0.9192 - val_loss: 0.4230 - val_accuracy: 0.8685
#
# Epoch 00030: loss improved from 0.23270 to 0.22961, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.030.h5
# Epoch 31/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.2245 - accuracy: 0.9214 - val_loss: 0.4458 - val_accuracy: 0.8717
#
# Epoch 00031: loss improved from 0.22961 to 0.22459, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.031.h5
# Epoch 32/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.2172 - accuracy: 0.9238 - val_loss: 0.4217 - val_accuracy: 0.8733
#
# Epoch 00032: loss improved from 0.22459 to 0.21720, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.032.h5
# Epoch 33/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 113s 72ms/step - loss: 0.2116 - accuracy: 0.9253 - val_loss: 0.4226 - val_accuracy: 0.8691
#
# Epoch 00033: loss improved from 0.21720 to 0.21160, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.033.h5
# Epoch 34/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.2111 - accuracy: 0.9244 - val_loss: 0.4284 - val_accuracy: 0.8731
#
# Epoch 00034: loss improved from 0.21160 to 0.21111, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.034.h5
# Epoch 35/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.2020 - accuracy: 0.9299 - val_loss: 0.4014 - val_accuracy: 0.8729
#
# Epoch 00035: loss improved from 0.21111 to 0.20191, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.035.h5
# Epoch 36/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.1976 - accuracy: 0.9305 - val_loss: 0.4111 - val_accuracy: 0.8735
#
# Epoch 00036: loss improved from 0.20191 to 0.19756, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.036.h5
# Epoch 37/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 110s 70ms/step - loss: 0.1915 - accuracy: 0.9321 - val_loss: 0.4045 - val_accuracy: 0.8799
#
# Epoch 00037: loss improved from 0.19756 to 0.19153, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.037.h5
# Epoch 38/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.1876 - accuracy: 0.9333 - val_loss: 0.4380 - val_accuracy: 0.8708
#
# Epoch 00038: loss improved from 0.19153 to 0.18759, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.038.h5
# Epoch 39/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.1833 - accuracy: 0.9354 - val_loss: 0.4025 - val_accuracy: 0.8797
#
# Epoch 00039: loss improved from 0.18759 to 0.18327, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.039.h5
# Epoch 40/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 111s 71ms/step - loss: 0.1776 - accuracy: 0.9365 - val_loss: 0.3721 - val_accuracy: 0.8902
#
# Epoch 00040: loss improved from 0.18327 to 0.17745, saving model to /home/zcc/Documents/cifar10_resnet/saved_models/cifar10_resnet_model.040.h5

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 5s 514us/step
# Test loss: 0.3720838087975979
# Test accuracy: 0.8902000188827515
