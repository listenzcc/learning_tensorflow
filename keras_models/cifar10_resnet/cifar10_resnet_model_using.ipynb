# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from pprint import pprint
import random
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
num_classes = 10
epochs = 100

# %%
model_dir, model_name = 'saved_models', 'cifar10_resnet_model.040.h5'
model = keras.models.load_model(os.path.join(model_dir, model_name))
keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, to_file='cifar10_resnet_model.png')

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape

# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Subtract pixel mean is enabled
X_train_mean = np.mean(X_train, axis=0)
X_train -= X_train_mean
X_test -= X_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 9s 884us/step
# Test loss: 0.37208384939432143
# Test accuracy: 0.8902000188827515

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.style.use('seaborn-dark')

for _ in range(3):
    fig = plt.figure(figsize=(6, 3))
    j = random.choice(range(len(X_test)))
    x = X_test[j]
    y = y_test[j]
    c = model.predict(x[np.newaxis, :])[0]
    x = ((x + X_train_mean) * 255).astype(np.uint32)
    axes = fig.subplots(1, 2)
    axes[0].imshow(x, interpolation='bilinear')
    axes[0].set_title("True: {} Guess: {}".format(np.argmax(y), np.argmax(c)))
    axes[1].barh(classes, c)
    axes[1].barh(classes[np.argmax(c)], c[np.argmax(c)])
    fig.tight_layout()

# %%
for j, layer in enumerate(model.layers):
    print(j, layer.name)
    weights = layer.get_weights()
    if weights:
        print(' ', weights[0].shape)
    print('')
# Out:
# 0 input_1
#
# 1 conv2d_1
#   (3, 3, 3, 16)
#
# 2 batch_normalization_1
#   (16,)
#
# 3 activation_1
#
# 4 batch_normalization_2
#   (16,)
#
# 5 activation_2
#
# 6 conv2d_3
#   (1, 1, 16, 16)
#
# 7 batch_normalization_3
#   (16,)
#
# 8 activation_3
#
# 9 conv2d_4
#   (3, 3, 16, 16)
#
# 10 batch_normalization_4
#   (16,)
#
# 11 activation_4
#
# 12 conv2d_5
#   (1, 1, 16, 64)
#
# 13 conv2d_2
#   (1, 1, 16, 64)
#
# 14 add_1
#
# 15 batch_normalization_5
#   (64,)
#
# 16 activation_5
#
# 17 conv2d_6
#   (1, 1, 64, 16)
#
# 18 batch_normalization_6
#   (16,)
#
# 19 activation_6
#
# 20 conv2d_7
#   (3, 3, 16, 16)
#
# 21 batch_normalization_7
#   (16,)
#
# 22 activation_7
#
# 23 conv2d_8
#   (1, 1, 16, 64)
#
# 24 add_2
#
# 25 batch_normalization_8
#   (64,)
#
# 26 activation_8
#
# 27 conv2d_9
#   (1, 1, 64, 16)
#
# 28 batch_normalization_9
#   (16,)
#
# 29 activation_9
#
# 30 conv2d_10
#   (3, 3, 16, 16)
#
# 31 batch_normalization_10
#   (16,)
#
# 32 activation_10
#
# 33 conv2d_11
#   (1, 1, 16, 64)
#
# 34 add_3
#
# 35 batch_normalization_11
#   (64,)
#
# 36 activation_11
#
# 37 conv2d_13
#   (1, 1, 64, 64)
#
# 38 batch_normalization_12
#   (64,)
#
# 39 activation_12
#
# 40 conv2d_14
#   (3, 3, 64, 64)
#
# 41 batch_normalization_13
#   (64,)
#
# 42 activation_13
#
# 43 conv2d_15
#   (1, 1, 64, 128)
#
# 44 conv2d_12
#   (1, 1, 64, 128)
#
# 45 add_4
#
# 46 batch_normalization_14
#   (128,)
#
# 47 activation_14
#
# 48 conv2d_16
#   (1, 1, 128, 64)
#
# 49 batch_normalization_15
#   (64,)
#
# 50 activation_15
#
# 51 conv2d_17
#   (3, 3, 64, 64)
#
# 52 batch_normalization_16
#   (64,)
#
# 53 activation_16
#
# 54 conv2d_18
#   (1, 1, 64, 128)
#
# 55 add_5
#
# 56 batch_normalization_17
#   (128,)
#
# 57 activation_17
#
# 58 conv2d_19
#   (1, 1, 128, 64)
#
# 59 batch_normalization_18
#   (64,)
#
# 60 activation_18
#
# 61 conv2d_20
#   (3, 3, 64, 64)
#
# 62 batch_normalization_19
#   (64,)
#
# 63 activation_19
#
# 64 conv2d_21
#   (1, 1, 64, 128)
#
# 65 add_6
#
# 66 batch_normalization_20
#   (128,)
#
# 67 activation_20
#
# 68 conv2d_23
#   (1, 1, 128, 128)
#
# 69 batch_normalization_21
#   (128,)
#
# 70 activation_21
#
# 71 conv2d_24
#   (3, 3, 128, 128)
#
# 72 batch_normalization_22
#   (128,)
#
# 73 activation_22
#
# 74 conv2d_25
#   (1, 1, 128, 256)
#
# 75 conv2d_22
#   (1, 1, 128, 256)
#
# 76 add_7
#
# 77 batch_normalization_23
#   (256,)
#
# 78 activation_23
#
# 79 conv2d_26
#   (1, 1, 256, 128)
#
# 80 batch_normalization_24
#   (128,)
#
# 81 activation_24
#
# 82 conv2d_27
#   (3, 3, 128, 128)
#
# 83 batch_normalization_25
#   (128,)
#
# 84 activation_25
#
# 85 conv2d_28
#   (1, 1, 128, 256)
#
# 86 add_8
#
# 87 batch_normalization_26
#   (256,)
#
# 88 activation_26
#
# 89 conv2d_29
#   (1, 1, 256, 128)
#
# 90 batch_normalization_27
#   (128,)
#
# 91 activation_27
#
# 92 conv2d_30
#   (3, 3, 128, 128)
#
# 93 batch_normalization_28
#   (128,)
#
# 94 activation_28
#
# 95 conv2d_31
#   (1, 1, 128, 256)
#
# 96 add_9
#
# 97 batch_normalization_29
#   (256,)
#
# 98 activation_29
#
# 99 average_pooling2d_1
#
# 100 flatten_1
#
# 101 dense_1
#   (256, 10)
#
# 102 activation_30
