# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from pprint import pprint
import random
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 32
num_classes = 10
epochs = 100
data_augmentation = True
model_type = 'resnet_noshortcut'
input_shape = (32, 32, 3)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
Input = keras.layers.Input
Conv2D = keras.layers.Conv2D
Activation = keras.layers.Activation
BatchNormalization = keras.layers.BatchNormalization
AveragePooling2D = keras.layers.AveragePooling2D
Flatten = keras.layers.Flatten
Dropout = keras.layers.Dropout
Dense = keras.layers.Dense

def block_bac(inputs, filters, activation='relu', kernel_size=1, strides=1, padding='same'):
    b = BatchNormalization()(inputs)
    a = Activation(activation)(b)
    c = Conv2D(filters, kernel_size, strides=strides, padding=padding)(a)
    return c

def block_res(inputs, small, large, firstlayer=False, firststride=2):
    if firstlayer:
        s = Conv2D(filters=large, kernel_size=1, padding='same', strides=firststride)(inputs)
    else:
        s = inputs
    c = block_bac(inputs, filters=small, kernel_size=1)
    c = block_bac(c, filters=small, kernel_size=3)
    if firstlayer:
        c = block_bac(c, filters=large, kernel_size=1, strides=firststride)
    else:
        c = block_bac(c, filters=large, kernel_size=1, strides=1)
    return c
    

# Input block
i = Input(shape=input_shape)
c = Conv2D(filters=16, kernel_size=3, padding='same')(i)
b = BatchNormalization()(c)
a = Activation('relu')(b)

r = block_res(a, 16, 64, firstlayer=True, firststride=1)
r = block_res(r, 16, 64)
r = block_res(r, 16, 64)

r = block_res(r, 64, 128, firstlayer=True)
r = block_res(r, 64, 128)
r = block_res(r, 64, 128)

r = block_res(r, 128, 256, firstlayer=True)
r = block_res(r, 128, 256)
r = block_res(r, 128, 256)

b = BatchNormalization()(r)
a = Activation('relu')(b)
av = AveragePooling2D(8)(a)
f = Flatten()(av)
d = Dense(num_classes)(f)
ac = Activation('softmax')(d)

model = keras.Model(inputs=i, outputs=ac)

keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = keras.callbacks.ModelCheckpoint(filepath=filepath,
                                             monitor='loss',
                                             verbose=1,
                                             save_best_only=True)

lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)

lr_reducer = keras.callbacks.ReduceLROnPlateau(factor=np.sqrt(0.1),
                                               cooldown=0,
                                               patience=5,
                                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10, 10))
for i in range(9):
    j = random.choice(range(len(X_train)))
    ax = fig.add_subplot(3, 3, i+1)
    ax.imshow(X_train[j], interpolation='bilinear')
    ax.set_title('{}'.format(classes[y_train[j][0]]))
    ax.axis('off')
fig.tight_layout()

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# 50000 train samples
# 10000 test samples

# %%
# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Subtract pixel mean is enabled
X_train_mean = np.mean(X_train, axis=0)
X_train -= X_train_mean
X_test -= X_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

datagen = keras.preprocessing.image.ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

datagen.fit(X_train)

# %%
fig = plt.figure(figsize=(5, 5))
for i in range(3):
    ax1 = fig.add_subplot(3, 2, i*2+1)
    ax2 = fig.add_subplot(3, 2, i*2+2)
    
    j = random.choice(range(len(X_train)))
    x = X_train[j]
    y = datagen.random_transform(x)
    
    ax1.imshow(x[:, :, 0], interpolation='bilinear')
    ax1.set_title("Raw")
    ax1.axis('off')
    
    ax2.imshow(y[:, :, 0], interpolation='bilinear')
    ax2.set_title("Transform")
    ax2.axis('off')
fig.tight_layout()

# %%
model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                    epochs=40,
                    validation_data=(X_test, y_test),
                    workers=32,
                    callbacks=callbacks)
# Out:
# Epoch 1/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 136s 87ms/step - loss: 1.6349 - accuracy: 0.3926 - val_loss: 1.8416 - val_accuracy: 0.4072
#
# Epoch 00001: loss improved from inf to 1.63498, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.001.h5
# Epoch 2/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 78ms/step - loss: 1.2599 - accuracy: 0.5487 - val_loss: 2.3290 - val_accuracy: 0.3910
#
# Epoch 00002: loss improved from 1.63498 to 1.25995, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.002.h5
# Epoch 3/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 1.0566 - accuracy: 0.6225 - val_loss: 1.3329 - val_accuracy: 0.5645
#
# Epoch 00003: loss improved from 1.25995 to 1.05669, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.003.h5
# Epoch 4/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 78ms/step - loss: 0.9201 - accuracy: 0.6771 - val_loss: 0.9877 - val_accuracy: 0.6609
#
# Epoch 00004: loss improved from 1.05669 to 0.92011, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.004.h5
# Epoch 5/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.8291 - accuracy: 0.7114 - val_loss: 1.0905 - val_accuracy: 0.6514
#
# Epoch 00005: loss improved from 0.92011 to 0.82898, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.005.h5
# Epoch 6/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.7594 - accuracy: 0.7358 - val_loss: 0.9094 - val_accuracy: 0.7120
#
# Epoch 00006: loss improved from 0.82898 to 0.75943, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.006.h5
# Epoch 7/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.7044 - accuracy: 0.7543 - val_loss: 0.9428 - val_accuracy: 0.6959
#
# Epoch 00007: loss improved from 0.75943 to 0.70441, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.007.h5
# Epoch 8/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.6604 - accuracy: 0.7703 - val_loss: 1.1680 - val_accuracy: 0.6353
#
# Epoch 00008: loss improved from 0.70441 to 0.66048, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.008.h5
# Epoch 9/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.6204 - accuracy: 0.7868 - val_loss: 0.7692 - val_accuracy: 0.7526
#
# Epoch 00009: loss improved from 0.66048 to 0.62047, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.009.h5
# Epoch 10/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5952 - accuracy: 0.7957 - val_loss: 0.7251 - val_accuracy: 0.7539
#
# Epoch 00010: loss improved from 0.62047 to 0.59532, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.010.h5
# Epoch 11/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.5629 - accuracy: 0.8064 - val_loss: 0.7069 - val_accuracy: 0.7581
#
# Epoch 00011: loss improved from 0.59532 to 0.56273, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.011.h5
# Epoch 12/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.5422 - accuracy: 0.8129 - val_loss: 0.6889 - val_accuracy: 0.7819
#
# Epoch 00012: loss improved from 0.56273 to 0.54228, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.012.h5
# Epoch 13/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.5146 - accuracy: 0.8226 - val_loss: 0.5526 - val_accuracy: 0.8116
#
# Epoch 00013: loss improved from 0.54228 to 0.51463, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.013.h5
# Epoch 14/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.4994 - accuracy: 0.8270 - val_loss: 0.6540 - val_accuracy: 0.7880
#
# Epoch 00014: loss improved from 0.51463 to 0.49938, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.014.h5
# Epoch 15/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.4887 - accuracy: 0.8303 - val_loss: 0.6006 - val_accuracy: 0.8016
#
# Epoch 00015: loss improved from 0.49938 to 0.48870, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.015.h5
# Epoch 16/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.4679 - accuracy: 0.8374 - val_loss: 0.7021 - val_accuracy: 0.7794
#
# Epoch 00016: loss improved from 0.48870 to 0.46793, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.016.h5
# Epoch 17/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.4481 - accuracy: 0.8458 - val_loss: 0.5763 - val_accuracy: 0.8087
#
# Epoch 00017: loss improved from 0.46793 to 0.44816, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.017.h5
# Epoch 18/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.4341 - accuracy: 0.8498 - val_loss: 0.5338 - val_accuracy: 0.8216
#
# Epoch 00018: loss improved from 0.44816 to 0.43410, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.018.h5
# Epoch 19/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.4232 - accuracy: 0.8520 - val_loss: 0.6561 - val_accuracy: 0.7960
#
# Epoch 00019: loss improved from 0.43410 to 0.42306, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.019.h5
# Epoch 20/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.4092 - accuracy: 0.8578 - val_loss: 0.6749 - val_accuracy: 0.7898
#
# Epoch 00020: loss improved from 0.42306 to 0.40926, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.020.h5
# Epoch 21/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.4003 - accuracy: 0.8606 - val_loss: 0.4758 - val_accuracy: 0.8414
#
# Epoch 00021: loss improved from 0.40926 to 0.40024, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.021.h5
# Epoch 22/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.3885 - accuracy: 0.8656 - val_loss: 0.5204 - val_accuracy: 0.8226
#
# Epoch 00022: loss improved from 0.40024 to 0.38857, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.022.h5
# Epoch 23/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.3784 - accuracy: 0.8697 - val_loss: 0.5529 - val_accuracy: 0.8198
#
# Epoch 00023: loss improved from 0.38857 to 0.37837, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.023.h5
# Epoch 24/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 76ms/step - loss: 0.3665 - accuracy: 0.8721 - val_loss: 0.6474 - val_accuracy: 0.8029
#
# Epoch 00024: loss improved from 0.37837 to 0.36648, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.024.h5
# Epoch 25/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.3573 - accuracy: 0.8754 - val_loss: 0.5062 - val_accuracy: 0.8305
#
# Epoch 00025: loss improved from 0.36648 to 0.35733, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.025.h5
# Epoch 26/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.3452 - accuracy: 0.8795 - val_loss: 0.5202 - val_accuracy: 0.8285
#
# Epoch 00026: loss improved from 0.35733 to 0.34520, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.026.h5
# Epoch 27/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.3383 - accuracy: 0.8830 - val_loss: 0.5092 - val_accuracy: 0.8327
#
# Epoch 00027: loss improved from 0.34520 to 0.33831, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.027.h5
# Epoch 28/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.3294 - accuracy: 0.8844 - val_loss: 0.4514 - val_accuracy: 0.8541
#
# Epoch 00028: loss improved from 0.33831 to 0.32940, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.028.h5
# Epoch 29/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.3233 - accuracy: 0.8878 - val_loss: 0.5340 - val_accuracy: 0.8317
#
# Epoch 00029: loss improved from 0.32940 to 0.32327, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.029.h5
# Epoch 30/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.3170 - accuracy: 0.8897 - val_loss: 0.5172 - val_accuracy: 0.8439
#
# Epoch 00030: loss improved from 0.32327 to 0.31698, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.030.h5
# Epoch 31/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.3047 - accuracy: 0.8927 - val_loss: 0.5382 - val_accuracy: 0.8214
#
# Epoch 00031: loss improved from 0.31698 to 0.30479, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.031.h5
# Epoch 32/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.3015 - accuracy: 0.8942 - val_loss: 0.5850 - val_accuracy: 0.8177
#
# Epoch 00032: loss improved from 0.30479 to 0.30144, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.032.h5
# Epoch 33/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.2951 - accuracy: 0.8967 - val_loss: 0.4595 - val_accuracy: 0.8516
#
# Epoch 00033: loss improved from 0.30144 to 0.29510, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.033.h5
# Epoch 34/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.2903 - accuracy: 0.8976 - val_loss: 0.5016 - val_accuracy: 0.8413
#
# Epoch 00034: loss improved from 0.29510 to 0.29031, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.034.h5
# Epoch 35/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.2871 - accuracy: 0.9005 - val_loss: 0.5153 - val_accuracy: 0.8397
#
# Epoch 00035: loss improved from 0.29031 to 0.28716, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.035.h5
# Epoch 36/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 76ms/step - loss: 0.2777 - accuracy: 0.9021 - val_loss: 0.4709 - val_accuracy: 0.8531
#
# Epoch 00036: loss improved from 0.28716 to 0.27762, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.036.h5
# Epoch 37/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.2699 - accuracy: 0.9067 - val_loss: 0.5435 - val_accuracy: 0.8320
#
# Epoch 00037: loss improved from 0.27762 to 0.26996, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.037.h5
# Epoch 38/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.2692 - accuracy: 0.9049 - val_loss: 0.4503 - val_accuracy: 0.8515
#
# Epoch 00038: loss improved from 0.26996 to 0.26914, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.038.h5
# Epoch 39/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.2642 - accuracy: 0.9067 - val_loss: 0.4588 - val_accuracy: 0.8508
#
# Epoch 00039: loss improved from 0.26914 to 0.26420, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.039.h5
# Epoch 40/40
# Learning rate:  0.001
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.2546 - accuracy: 0.9110 - val_loss: 0.5902 - val_accuracy: 0.8247
#
# Epoch 00040: loss improved from 0.26420 to 0.25452, saving model to /home/zcc/Documents/cifar10_resnet_noshortcut/saved_models/cifar10_resnet_noshortcut_model.040.h5

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 6s 561us/step
# Test loss: 0.5901517169237137
# Test accuracy: 0.8246999979019165
