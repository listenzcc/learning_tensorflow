# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from pprint import pprint
import random
import os

# %%
batch_size = 32
num_classes = 10
epochs = 100

# %%
model_dir, model_name = 'saved_models', 'cifar10_resnet_noshortcut_model.040.h5'
model = keras.models.load_model(os.path.join(model_dir, model_name))
keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, to_file='cifar10_resnet_model.png')

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape

# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# Subtract pixel mean is enabled
X_train_mean = np.mean(X_train, axis=0)
X_train -= X_train_mean
X_test -= X_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test = keras.utils.np_utils.to_categorical(y_test, num_classes)

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 9s 911us/step
# Test loss: 0.5901516921520233
# Test accuracy: 0.8246999979019165

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.style.use('seaborn-dark')

for _ in range(3):
    fig = plt.figure(figsize=(6, 3))
    j = random.choice(range(len(X_test)))
    x = X_test[j]
    y = y_test[j]
    c = model.predict(x[np.newaxis, :])[0]
    x = ((x + X_train_mean) * 255).astype(np.uint32)
    axes = fig.subplots(1, 2)
    axes[0].imshow(x, interpolation='bilinear')
    axes[0].set_title("True: {} Guess: {}".format(np.argmax(y), np.argmax(c)))
    axes[1].barh(classes, c)
    axes[1].barh(classes[np.argmax(c)], c[np.argmax(c)])
    fig.tight_layout()

# %%
for j, layer in enumerate(model.layers):
    print(j, layer.name)
    weights = layer.get_weights()
    if weights:
        print(' ', weights[0].shape)
    print('')
# Out:
# 0 input_1
#
# 1 conv2d_1
#   (3, 3, 3, 16)
#
# 2 batch_normalization_1
#   (16,)
#
# 3 activation_1
#
# 4 batch_normalization_2
#   (16,)
#
# 5 activation_2
#
# 6 conv2d_3
#   (1, 1, 16, 16)
#
# 7 batch_normalization_3
#   (16,)
#
# 8 activation_3
#
# 9 conv2d_4
#   (3, 3, 16, 16)
#
# 10 batch_normalization_4
#   (16,)
#
# 11 activation_4
#
# 12 conv2d_5
#   (1, 1, 16, 64)
#
# 13 batch_normalization_5
#   (64,)
#
# 14 activation_5
#
# 15 conv2d_6
#   (1, 1, 64, 16)
#
# 16 batch_normalization_6
#   (16,)
#
# 17 activation_6
#
# 18 conv2d_7
#   (3, 3, 16, 16)
#
# 19 batch_normalization_7
#   (16,)
#
# 20 activation_7
#
# 21 conv2d_8
#   (1, 1, 16, 64)
#
# 22 batch_normalization_8
#   (64,)
#
# 23 activation_8
#
# 24 conv2d_9
#   (1, 1, 64, 16)
#
# 25 batch_normalization_9
#   (16,)
#
# 26 activation_9
#
# 27 conv2d_10
#   (3, 3, 16, 16)
#
# 28 batch_normalization_10
#   (16,)
#
# 29 activation_10
#
# 30 conv2d_11
#   (1, 1, 16, 64)
#
# 31 batch_normalization_11
#   (64,)
#
# 32 activation_11
#
# 33 conv2d_13
#   (1, 1, 64, 64)
#
# 34 batch_normalization_12
#   (64,)
#
# 35 activation_12
#
# 36 conv2d_14
#   (3, 3, 64, 64)
#
# 37 batch_normalization_13
#   (64,)
#
# 38 activation_13
#
# 39 conv2d_15
#   (1, 1, 64, 128)
#
# 40 batch_normalization_14
#   (128,)
#
# 41 activation_14
#
# 42 conv2d_16
#   (1, 1, 128, 64)
#
# 43 batch_normalization_15
#   (64,)
#
# 44 activation_15
#
# 45 conv2d_17
#   (3, 3, 64, 64)
#
# 46 batch_normalization_16
#   (64,)
#
# 47 activation_16
#
# 48 conv2d_18
#   (1, 1, 64, 128)
#
# 49 batch_normalization_17
#   (128,)
#
# 50 activation_17
#
# 51 conv2d_19
#   (1, 1, 128, 64)
#
# 52 batch_normalization_18
#   (64,)
#
# 53 activation_18
#
# 54 conv2d_20
#   (3, 3, 64, 64)
#
# 55 batch_normalization_19
#   (64,)
#
# 56 activation_19
#
# 57 conv2d_21
#   (1, 1, 64, 128)
#
# 58 batch_normalization_20
#   (128,)
#
# 59 activation_20
#
# 60 conv2d_23
#   (1, 1, 128, 128)
#
# 61 batch_normalization_21
#   (128,)
#
# 62 activation_21
#
# 63 conv2d_24
#   (3, 3, 128, 128)
#
# 64 batch_normalization_22
#   (128,)
#
# 65 activation_22
#
# 66 conv2d_25
#   (1, 1, 128, 256)
#
# 67 batch_normalization_23
#   (256,)
#
# 68 activation_23
#
# 69 conv2d_26
#   (1, 1, 256, 128)
#
# 70 batch_normalization_24
#   (128,)
#
# 71 activation_24
#
# 72 conv2d_27
#   (3, 3, 128, 128)
#
# 73 batch_normalization_25
#   (128,)
#
# 74 activation_25
#
# 75 conv2d_28
#   (1, 1, 128, 256)
#
# 76 batch_normalization_26
#   (256,)
#
# 77 activation_26
#
# 78 conv2d_29
#   (1, 1, 256, 128)
#
# 79 batch_normalization_27
#   (128,)
#
# 80 activation_27
#
# 81 conv2d_30
#   (3, 3, 128, 128)
#
# 82 batch_normalization_28
#   (128,)
#
# 83 activation_28
#
# 84 conv2d_31
#   (1, 1, 128, 256)
#
# 85 batch_normalization_29
#   (256,)
#
# 86 activation_29
#
# 87 average_pooling2d_1
#
# 88 flatten_1
#
# 89 dense_1
#   (256, 10)
#
# 90 activation_30
